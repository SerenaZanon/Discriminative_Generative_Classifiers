# %%
# %matplotlib inline

import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score,confusion_matrix
import seaborn as sns
import time

# %% [markdown]
# # Random Forest
#
# The model Random Decision Forest is applied with a 10 folds cross validation in order to indetify the best value for the parameter n_estimators.

# %%
# Retrieving the DataFrame
X_train_small = pd.read_csv('X_train_small.csv')
y_train_small = pd.read_csv('y_train_small.csv')

X_train = pd.read_csv('X_train.csv')
y_train = pd.read_csv('y_train.csv')

X_test = pd.read_csv('X_test.csv')
y_test = pd.read_csv('y_test.csv')

# %%
# Printing their shape
print("X_train_small shape:", X_train_small.shape)
print("y_train_small shape:", y_train_small.shape)
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
print("X_test shape:", X_test.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train_small shape: (15000, 719)
# y_train_small shape: (15000, 1)
# X_train shape: (60000, 719)
# y_train shape: (60000, 1)
# X_test shape: (10000, 719)
# y_test shape: (10000, 1)

# %%
def cv10_rf(X_train_small, X_train, X_test, y_train_small, y_train, y_test):
    
    
    # ------------------------------------------------------------------
    
    # Creation of the model
    model = RandomForestClassifier(criterion = 'entropy')
    properties = {'n_estimators': [x for x in range(100,1100,100)]}
    
    # Applying the cross validation technique over the model and finding the best hyper-parameter value
    tuned_model = GridSearchCV(model, properties, scoring = "accuracy", cv = 10, verbose = 0, n_jobs = 4)
    print("Fitting with GSCV...")
    tuned_model.fit(X_train_small, y_train_small)
    
    best_accuracy = tuned_model.best_score_
    best_n_trees = tuned_model.best_params_
    result = pd.DataFrame(tuned_model.cv_results_)
        
    # ------------------------------------------------------------------

    # Fitting the best model on the whole training set
    best_model = tuned_model.best_estimator_
    print("Fitting ...")
    start_fit = time.time() 
    best_model.fit(X_train, y_train)
    end_fit = time.time()
    time_fit = end_fit - start_fit

    # Predicting on the test set
    print("Predicting ...")
    start_predict = time.time()
    y_pred_test = best_model.predict(X_test)
    end_predict = time.time()
    test_acc = accuracy_score(y_true = y_test, y_pred = y_pred_test)    
    time_predict = end_predict - start_predict
    
    time_count = [time_fit, time_predict]

    return best_n_trees, best_accuracy, test_acc, y_pred_test, result, time_count

# %%
best_n_trees, best_accuracy, test_acc, y_pred_test, results, time_count = cv10_rf(X_train_small, X_train, X_test, y_train_small.to_numpy().ravel(), y_train.to_numpy().ravel(), y_test.to_numpy().ravel())
# Out:
# Fitting with GSCV...
# Fitting ...
# Predicting ...

# %%
print(results[["param_n_estimators", "mean_test_score"]])
print("Best number of estimators: ", best_n_trees)
print("Best accuracy with the best number of estimators: ", best_accuracy)
print("Test accuracy with the best number of estimators: ", test_acc)
print("Time for the fit phase: ", time_count[0])
print("Time for the predict phase: ", time_count[1])
# Out:
#   param_n_estimators  mean_test_score
# 0                100         0.953467
# 1                200         0.954467
# 2                300         0.954533
# 3                400         0.954867
# 4                500         0.955333
# 5                600         0.955200
# 6                700         0.955200
# 7                800         0.956200
# 8                900         0.955533
# 9               1000         0.955600
# Best number of estimators:  {'n_estimators': 800}
# Best accuracy with the best number of estimators:  0.9561999999999999
# Test accuracy with the best number of estimators:  0.9684
# Time for the fit phase:  456.9846067428589
# Time for the predict phase:  2.150967836380005

# %%
cf_matrix = confusion_matrix(y_test, y_pred_test)
sns.heatmap(cf_matrix, annot=True)
# Out:
# <Axes: >
